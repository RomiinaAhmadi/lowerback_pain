# %% [markdown]
# بخش اول :
#
# تعیین اهداف کسب و‌کار ( determine project objectives)
#
# کمردرد یکی از شایع ترین مشکلات هستش و تشخیص سریعش میتونه از مشکلات ستون فقرات جلوگیری کنه
# و هزینه درمان کمتر بشه و این پروژه میتونه یک ابزار کمکی باشه

# %% [markdown]
# موفقیت این پروژه این هستش که بتونیم با هزینه کم و قبل از به وجود اومدن مشکلات جدی مشکل ستون فقرات رو تشخیص بدیم

# %% [markdown]
# بخش دوم:
#
# ارزیابی وضعیت موجود  (access situation)
#
# این بخش میشه به چند ریز مجموعه تقسیم کرد
#
# ۱- فهرست منابع موجود
#
# ابزار هایی دارم مثل
#
# Numpy pandas scikit-learn jupyterlab notebook matplotlib seaborn python
#
#
# همچین دیتا ستی دارم که ۳۱۰ رکود و ۱۳ ستون داره

# %% [markdown]
# ۲- نیازمندی ها ، فرضیات و محدودیت ها
#
# ددلاین تحویل این پروژه حدود ۱۰ روز هستش و محدودیتی ندارم
#
# ۳- ریسک ها و برنامه های احتیاطی
#
# اگر دقت پایین اومد چیکار کنم؟
#
# اگر دقت مدل پایین بود باید الگوریتم های دیگه تست کنم تا دقت قابل قبولی داشته باشه
#
# اگر دیتا اوت لایر و داده های گمشده داشت چیکار کنم؟
#
# با توجه به اینکه داده ها از دنیای واقعی گرفتیم و مربوط به سلامتی هستش نمیشه ریسک کرد سرش و با توجه به شرایط باید حذف یا درست بشه
#
# و با توجه به اینکه حجم داده کم هستش ریسک overfitting خیلی پایین هستش

# %% [markdown]
# ۴- اصطلاحات تخصصی دیتا ست
#
# pelvic_incidence
#
# زاویه لگن
#
# pelvic_tilt - pelvic_slope
#
# شیب لگن
#
# lumbar_lordosis_angle
#
# زاویه قوس کمر
#
# sacral_slope
#
# شیب استخوان خاجی
#
#  pelvic_radius
#
# شعاع لگن
#
# degree_spondylolisthesis
#
# میزان لغزش مهره ها
#
# direct_tilt
#
# انحراف مستقیم
#
# thoracic_slope
#
#
# شيب ناحيه سينه اى ستون فقرات
#
# cervical_tilt
#
# شیب گردن
#
# sacrum_angle
#
# زاويه استخوان خاجى
#
# scoliosis_slope
#
# شیب اسکولیوز

# %% [markdown]
# بخش سوم:
#
# تعیین اهداف داده‌کاوی
# (Determine Data Mining Goals)
#
# نوع مسئله چیه؟ Classification، Regression یا Clustering؟
#
# بخاطر اینکه فیلد هدف داریم احتمالا classification ولی بازم نیاز به بررسی هستش
#
# معیار ارزیابی دقیقا چیه؟ فقط Accuracy یا باید Precision، Recall، F1-score هم بسنجیم؟
#
# چون تو حوزه پزشکی، تشخیص غلط منفی یعنی Recall خیلی مهمه پس هم دقت و هم recall باید بررسی بشه
#
# آیا میخوایم فقط پیش‌بینی کنیم یا تفسیرپذیری مدل هم مهمه؟
#
# بخاطر اینکه تو حوزه د
# پزشکی هستش تفسیر هم مهمه

# %% [markdown]
# بخش چهارم:
#
# تهیه برنامه پروژه
# (Produce Project Plan)
#
# مراحل بعدی که باید طی کنیم چیان؟
#
#
# چون از crisp-dm
# استفاده میکنیم ۷ مرحله داره و مراحل بعدی:
#
# (Data Understanding، Data Preparation، Modeling، Evaluation، Deployment)
#
# برای هر مرحله چه ابزاری استفاده میکنیم؟
#
# برای دو مرحله بعدی بیشتر از
#
# Numpy, pandas, matplotlib, seaborn
#
# استفاده میکنیم و از
#
# Scikit-learn
#
# در مراحل ۴ به بعد استفاده میشه
#
#
# زمان‌بندی تقریبی هر مرحله چقدره؟
#
# زمان بر ترین مرحله مرحله سوم هستش که فکر میکنم یک روز و نیم تا ۳ روز برای این پروژه زمان احتیاح داشته باشه بقیه مراحل در یک روز یا دو روز تکمیل میشن
