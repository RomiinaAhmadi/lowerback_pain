# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

df = pd.read_csv("data/Dataset_spine.csv")
df
# Out:
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0           63.027817    22.552586              39.609117     40.475232
# 1           39.056951    10.060991              25.015378     28.995960
# 2           68.832021    22.218482              50.092194     46.613539
# 3           69.297008    24.652878              44.311238     44.644130
# 4           49.712859     9.652075              28.317406     40.060784
# ..                ...          ...                    ...           ...
# 305         47.903565    13.616688              36.000000     34.286877
# 306         53.936748    20.721496              29.220534     33.215251
# 307         61.446597    22.694968              46.170347     38.751628
# 308         45.252792     8.693157              41.583126     36.559635
# 309         33.841641     5.073991              36.641233     28.767649
#
#      pelvic_radius  degree_spondylolisthesis  pelvic_slope  Direct_tilt  \
# ...

# %% [markdown]
# بخش 1:
#
# collect initial data(جمع اوری داده اولیه)

# %%
df.head()
# Out:
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027817    22.552586              39.609117     40.475232
# 1         39.056951    10.060991              25.015378     28.995960
# 2         68.832021    22.218482              50.092194     46.613539
# 3         69.297008    24.652878              44.311238     44.644130
# 4         49.712859     9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis  pelvic_slope  Direct_tilt  \
# 0      98.672917                 -0.254400      0.744503      12.5661
# 1     114.405425                  4.564259      0.415186      12.8874
# 2     105.985135                 -3.530317      0.474889      26.8343
# 3     101.868495                 11.211523      0.369345      23.5603
# 4     108.168725                  7.918501      0.543360      35.4940
#
#    thoracic_slope  cervical_tilt  sacrum_angle  scoliosis_slope Class_att
# ...

# %%
df.shape
# Out:
# (310, 13)

# %% [markdown]
# این دیتا ست 13 ستون داره که بجز فید هدف همه ستون ها عددی هستند
#
# و 310 رکورد داره که تقریبا میشه گفت دیتا ست کوچکی هستش

# %%
df.columns
# Out:
# Index(['pelvic_incidence', 'pelvic_tilt', 'lumbar_lordosis_angle',
#        'sacral_slope', 'pelvic_radius', 'degree_spondylolisthesis',
#        'pelvic_slope', 'Direct_tilt', 'thoracic_slope', 'cervical_tilt',
#        'sacrum_angle', 'scoliosis_slope', 'Class_att'],
#       dtype='str')

# %% [markdown]
# یک دیده اولیه به داده هامون تا اینجا بدست اوردیم که نشون میده داده ها دقیقا چقدر هستند نام ستون ها چیه

# %% [markdown]
# بخش 2:
#
# describe data(توصیف داده ها )

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pelvic_incidence          310 non-null    float64
#  1   pelvic_tilt               310 non-null    float64
#  2   lumbar_lordosis_angle     310 non-null    float64
#  3   sacral_slope              310 non-null    float64
#  4   pelvic_radius             310 non-null    float64
#  5   degree_spondylolisthesis  310 non-null    float64
#  6   pelvic_slope              310 non-null    float64
#  7   Direct_tilt               310 non-null    float64
#  8   thoracic_slope            310 non-null    float64
#  9   cervical_tilt             310 non-null    float64
#  10  sacrum_angle              310 non-null    float64
#  11  scoliosis_slope           310 non-null    float64
#  12  Class_att                 310 non-null    str
# dtypes: float64(12), str(1)
# ...

# %% [markdown]
# هر12 ستون داده هاشون اندازه رکورد هستش و نوع 12 ستونfloat64 هستش و اخرین ستون که فیلد هدفمون هم هست استرینگه

# %%
df.describe()
# Out:
#        pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# count        310.000000   310.000000             310.000000    310.000000
# mean          60.496653    17.542822              51.930930     42.953831
# std           17.236520    10.008330              18.554064     13.423102
# min           26.147921    -6.554948              14.000000     13.366931
# 25%           46.430294    10.667069              37.000000     33.347122
# 50%           58.691038    16.357689              49.562398     42.404912
# 75%           72.877696    22.120395              63.000000     52.695888
# max          129.834041    49.431864             125.742385    121.429566
#
#        pelvic_radius  degree_spondylolisthesis  pelvic_slope  Direct_tilt  \
# count     310.000000                310.000000    310.000000   310.000000
# mean      117.920655                 26.296694      0.472979    21.321526
# std        13.317377                 37.559027      0.285787     8.639423
# ...

# %% [markdown]
# ستون degree_spondylolisthesis   میانگین با حداکثر و حداقل خیلی فاصله داره میتونه داده های پرت  داشته باشه و نیاز به برری داره

# %%
df['Class_att'].value_counts()
# Out:
# Class_att
# Abnormal    210
# Normal      100
# Name: count, dtype: int64

# %% [markdown]
# فیلد هدف 2 متغیر داره نرمال و غیر نرمال
#
# تعداد افراد نرمال 100و تعداد افراد غیر نرمال 210 نفر هستش

# %% [markdown]
# بخش 3:
#
# explore data(کاوش  داده)

# %%
df.hist(figsize=(15,10), bins=30)
# Out:
# array([[<Axes: title={'center': 'pelvic_incidence'}>,
#         <Axes: title={'center': 'pelvic_tilt'}>,
#         <Axes: title={'center': 'lumbar_lordosis_angle'}>],
#        [<Axes: title={'center': 'sacral_slope'}>,
#         <Axes: title={'center': 'pelvic_radius'}>,
#         <Axes: title={'center': 'degree_spondylolisthesis'}>],
#        [<Axes: title={'center': 'pelvic_slope'}>,
#         <Axes: title={'center': 'Direct_tilt'}>,
#         <Axes: title={'center': 'thoracic_slope'}>],
#        [<Axes: title={'center': 'cervical_tilt'}>,
#         <Axes: title={'center': 'sacrum_angle'}>,
#         <Axes: title={'center': 'scoliosis_slope'}>]], dtype=object)

# %% [markdown]
# نمودار اول و دوم:
#
# تقریبا نرمال ولی یکم به راست کشیدگی دارن
#
# نمودار سوم:
#
# چولگی راست داره
#
# نمودار چهارم:
#
# یکم چولگی راست داره
#
# نمودار پنجم:
#
# تا اینجا نرمال ترین توزیع رو داره ولی با یکم چولگی چپ
#
# نمودار ششم:
#
# چولگی شدییید به راست داره
#
# نمودار هفتم تا دوازدهم:
#
# همشون تقریبا متقارن هستند و اصلا زنگوله ای نیستند

# %%
df.boxplot(figsize=(15,10), rot=90)
# Out:
# <Axes: >

# %% [markdown]
# باکس اول سوم وچارک زیاد داده پرت نداره . و داده های پرتشون هم نزویک به باکس هستن ولی
#
# نمودار دوم و پنجم داده های پرت زیاد زیادی دارند
#
# نمودار ششم چندین داده پرت داره ولی یکی از داده های پرتش خیلی دور تر از حالت عادی هستش
#
# که احتمال داره اشتباه ثبتی باشه
#
# 6 باکس اخر داده پرت ندارند

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(numeric_only=True),annot=True ,fmt=".2f")
plt.show()

# %% [markdown]
# قوی ترین همبستگی های مثبت رو ستون اولی داره
#
# و قئی ترین همبستگی های منفی رو ستون پنجم داره
#
# قوی ترین همبستگی مثبت :
#
# اولی با چهارمی با ضریب 0.81
#
# بعدش اولی با سومی با ضریب 0.72
#
# بعدش اولی با ششمی با ضریب 0.64
#
# بعدش اولی با دومی با ضریب 0.63
#
#
# قوی ترین همبستگی منفی:
#
# چهارمی با پنجمی با ضریب -0.34
#
# اولی با پنجمی با ضریب -0.25
